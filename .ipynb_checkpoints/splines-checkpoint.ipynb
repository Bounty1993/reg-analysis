# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X = np.linspace(-5, 5, 200)
Y_org = np.sin(X) + 3
Y = Y_org + np.random.randn(200) * 0.5
plt.scatter(X, Y)
plt.plot(X, Y_org)

# %%
mask = (X > -2) & (X < 2)
temp_y = Y[mask].mean()
temp_x = X[mask]
plt.scatter(X, Y)
plt.plot(temp_x, np.full(temp_x.shape[0], temp_y))
