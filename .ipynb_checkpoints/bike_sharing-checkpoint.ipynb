# %% [markdown]
# Bike sharing systems are a means of renting bicycles where the process of obtaining membership, rental, and bike return is automated via a network of kiosk locations throughout a city. Using these systems, people are able rent a bike from a one location and return it to a different place on an as-needed basis. Currently, there are over 500 bike-sharing programs around the world.
#
# The data generated by these systems makes them attractive for researchers because the duration of travel, departure location, arrival location, and time elapsed is explicitly recorded. Bike sharing systems therefore function as a sensor network, which can be used for studying mobility in a city. In this notebook I will try to predict number of rented bikes

# %%
import warnings
import os
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings("ignore")

# %%
train_path = os.path.join('Datasets', 'bike', 'train.csv')
train_df = pd.read_csv(train_path, parse_dates=['datetime'])
train_df.drop(columns=['casual', 'registered'], inplace=True)

test_path = os.path.join('Datasets', 'bike', 'test.csv')
test_df = pd.read_csv(test_path, parse_dates=['datetime'])

# %%
print('Shape (train):', train_df.shape)
print('Shape (test):', test_df.shape)
print('Any missing values (train)?:', train_df.isna().any().any())
print('Any missing values (test)?:', test_df.isna().any().any())
train_df.head()
# Out:
# Shape (train): (10886, 10)
# Shape (test): (6493, 9)
# Any missing values (train)?: False
# Any missing values (test)?: False
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  count
# 0        81        0.0     16
# 1        80        0.0     40
# 2        80        0.0     32
# 3        75        0.0     13
# 4        75        0.0      1

# %% [markdown]
# Dataset is not large. There are only 10866 rows in train dataset and 6493 in testset. Moreover there are no missing values.

# %% [markdown]
# ### Data Fields
#
# * datetime - hourly date + timestamp
# * season -  1 = spring, 2 = summer, 3 = fall, 4 = winter
# * holiday - whether the day is considered a holiday
# * whether the day is neither a weekend nor holiday
# * weather
#     1. Clear, Few clouds, Partly cloudy, Partly cloudy
#     2. Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
#     3. Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
#     4. Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# * temp - temperature in Celsius
# * atemp - "feels like" temperature in Celsius
# * humidity - relative humidity
# * windspeed - wind speed
# * casual - number of non-registered user rentals initiated
# * registered - number of registered user rentals initiated
# * count - number of total rentals

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
sns.distplot(train_df['count'], ax=ax1)
ax1.set_title('Count distribution')
sns.distplot(np.log(train_df['count']), ax=ax2)
ax2.set_title('Count distribution after log')
ax2.set_xlabel('Log(count)');

# %% [markdown]
# Original target is extremely skewed. For most machine learning algorithms it is a problem and linear models are not exceptions. That is why I will change target variable using log function. The results is better but still distribution does not look like gaussian distribution.
#
# In that notebook I will not remove outliers. It is a popular method to remove all observations that are more distant from a median than a certain threshold. In  most of cases it works very well but here I think removing outliers would be misleading.

# %%
train_df['date'] = train_df['datetime'].dt.date
temp_df = train_df.groupby('date')['count'].mean()
temp_df = temp_df.reset_index()
plt.figure(figsize=(12,5))
plt.title('Bike sharing over time')
ax = sns.lineplot(x='date', y='count', data=temp_df)
ax.plot(temp_df['date'], temp_df['count'].rolling(30).mean())

# %% [markdown]
# Renting bikes is increasing over time. It seems that more people decide to rent a bike during warm months - it is not suprising.

# %%
train_df['year'] = train_df['datetime'].dt.year
train_df['month'] = train_df['datetime'].dt.month
train_df['weekday'] = train_df['datetime'].dt.weekday
train_df['hour'] = train_df['datetime'].dt.hour

# %%
fig, axes = plt.subplots(2, 2, figsize=(12,10))
ax1, ax2, ax3, ax4 = axes.flat
sns.boxplot(x='year', y='count', data=train_df, ax=ax1)
sns.boxplot(x='month', y='count', data=train_df, ax=ax2)
sns.boxplot(x='hour', y='count', data=train_df, ax=ax3)
sns.boxplot(x='holiday', y='count', data=train_df, ax=ax4)

# %% [markdown]
# The demand for bikes was higher in 2012 than in 2011. Maybe business is growing. Moreover people rent more bikes in April, June, July and September (it is holidays) but generally I expected bigger difference. It turns out than on average holidays are not any better than other days. I supose most people rent bikes because they use them to get to job or schools. I would explain why the biggest demand is in the morning and afternoon.

# %%
#train_df.drop(columns=['datetime', 'date'], inplace=True)
corr_mat = train_df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr_mat, annot=True, fmt='.2')

# %%
season_mapping = {1: 'spring', 2: 'summer', 3: 'fall', 4: 'winter'}
train_df['season'] = train_df['season'].map(season_mapping)

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
ax1, ax2, ax3, ax4 = axes.flat
sns.pointplot(x='hour', y='count', hue='season', data=train_df, ax=ax1)
sns.pointplot(x='hour', y='count', hue='workingday', data=train_df, ax=ax2)
sns.violinplot(x='weather', y='count', hue='workingday', data=train_df, ax=ax3)

# %%
sns.relplot(x='humidity', y='count', 
            col='season', hue='holiday',
            data=train_df)
sns.relplot(x='temp', y='count', 
            col='season', hue='holiday',
            data=train_df)

# %%
train_df['windy'] = 0
train_df.loc[train_df['windspeed'] != 0, 'windy'] = 1
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
sns.boxplot(x='windy', y='count', data=train_df, ax=ax1)
sns.scatterplot(x='windspeed', y='count', data=train_df, ax=ax2)

# %%
train_df.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'count', 'date', 'year', 'month',
#        'weekday', 'hour', 'windy'],
#       dtype='object')

# %% [markdown]
# ### Preprocessing

# %%
from sklearn.model_selection import train_test_split

# %%
train_df.sort_values(by=['datetime'], inplace=True)
train_df.drop(columns=['datetime', 'date'], inplace=True)

# %%
num_test = 2000
Y = np.log1p(train_df['count'])
X = train_df.drop(columns='count')
X = pd.get_dummies(X)
X_train, Y_train = X[:-2000], Y[:-2000]
X_valid, Y_valid = X[-2000:], Y[-2000:]
print(f'Train shape: {X_train.shape}, {Y_train.shape}')
print(f'Valid shape: {X_valid.shape}, {Y_valid.shape}')
# Out:
# Train shape: (8886, 16), (8886,)
# Valid shape: (2000, 16), (2000,)

# %%
test_datetimes = test_df['datetime']

test_df['year'] = test_df['datetime'].dt.year
test_df['month'] = test_df['datetime'].dt.month
test_df['weekday'] = test_df['datetime'].dt.weekday
test_df['hour'] = test_df['datetime'].dt.hour
test_df.drop(columns='datetime', inplace=True)

test_df['season'] = test_df['season'].map(season_mapping)
test_df['windy'] = 0
test_df.loc[test_df['windspeed'] != 0, 'windy'] = 1
test_df = pd.get_dummies(test_df)

# %% [markdown]
# ### Machine learning

# %%
from sklearn.linear_model import LinearRegression, RidgeCV, Lars, LassoCV
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error

# %%
def rmsle(Y_true, Y_pred):
    mse = mean_squared_error(Y_true, Y_pred)
    return np.sqrt(mse)

# %%
def add_poly(data):
    poly = PolynomialFeatures(degree=2)
    num_features = ['temp', 'humidity', 'windspeed', 'month', 'hour', 'weekday']
    poly_data = poly.fit_transform(data[num_features])
    rest_cols = [col for col in data.columns if col not in num_features]
    data = np.c_[data[rest_cols], poly_data]
    return data

X_train = add_poly(X_train)
X_valid = add_poly(X_valid)
X_test = add_poly(test_df)

# %% [markdown]
# ### Linear Regression

# %%
lr_model = LinearRegression(fit_intercept=True)
lr_model.fit(X_train, Y_train)
Y_pred = lr_model.predict(X_valid)

lr_score = rmsle(Y_valid, Y_pred)

# %% [markdown]
# ### LARS

# %%
lars_model = Lars(n_nonzero_coefs=15)
lars_model.fit(X_train, Y_train)
Y_pred_lars = lars_model.predict(X_valid)
lars_score = rmsle(Y_valid, Y_pred_lars)

# %% [markdown]
# ### PCR

# %%
pcr_pipeline = make_pipeline(StandardScaler(),
                             PCA(),
                             LinearRegression())
pcr_pipeline.fit(X_train, Y_train)
Y_pred_pcr = pcr_pipeline.predict(X_valid)
pcr_score = rmsle(Y_valid, Y_pred_pcr)

# %% [markdown]
# ### Ridge Regression

# %%
ridge_model = RidgeCV()
ridge_model.fit(X_train, Y_train)
Y_pred_ridge = ridge_model.predict(X_valid)

ridge_score = rmsle(Y_valid, Y_pred_ridge)

# %% [markdown]
# ### Lasso

# %%
lasso_pipeline = make_pipeline(StandardScaler(),
                               LassoCV())
lasso_pipeline.fit(X_train, Y_train)
Y_pred_lasso = lasso_pipeline.predict(X_valid)
lasso_score = rmsle(Y_valid, Y_pred_lasso)

# %% [markdown]
# ### Results

# %%
scores_df = pd.DataFrame([('Linear Regression', lr_score),
                          ('LARS', lars_score),
                          ('PCR', pcr_score),
                          ('Ridge', ridge_score),
                          ('Lasso', lasso_score)],
                         columns=['model', 'score'])
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
sns.barplot(x='model', y='score', data=scores_df, ax=ax1)
ax1.set_ylim(0.8, 0.9)
for index, row in scores_df.iterrows():
    ax1.text(index, (row['score'] + 0.002), round(row['score'], 4), 
            color='black', ha="center")
    
ax2.scatter(Y_valid, Y_pred_lasso, alpha=0.8, edgecolor='black')
ax2.set_xlabel('Validation')
ax2.set_ylabel('Predicted')
lr_temp = LinearRegression(fit_intercept=True).fit(Y_pred_lasso.reshape(-1,1), Y_valid)
ax2.plot(lr_temp.predict(Y_valid.to_numpy().reshape(-1,1)), Y_valid)
ax2.set_ylim(1.5, 7)
# Out:
# (1.5, 7)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
sns.distplot(Y_valid, label='Validation', ax=ax1)
sns.distplot(Y_pred_lasso, label='Predicted', ax=ax1)
ax1.legend(loc='upper left')
ax1.set_title('Values distribution')

residuals = Y_valid - Y_pred_lasso
sns.distplot(residuals, ax=ax2)
ax2.set_title('Residuals distribution')
# Out:
# Text(0.5, 1.0, 'Residuals distribution')

# %% [markdown]
# ### Trees
#
# The results for linear models are not perfectly satisfying. If you look at Leaderboard on Kaggle (https://www.kaggle.com/c/bike-sharing-demand/leaderboard) median RMSLE is about 0.495 - much lower than what we have. There are two possible reasons:
#
# 1. More sofisticated features engineering is needed
# 2. More flexible model is needed
#
# I will try to use RandomForestRegressor to check whether number 1 or 2 is true

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(n_estimators=100, max_depth=20)
rf_model.fit(X_train, Y_train)
Y_pred_rf = rf_model.predict(X_valid)
rmsle(Y_valid, Y_pred_rf)
# Out:
# 0.392079933488875

# %%
Y_final = rf_model.predict(X_test)
submission = pd.DataFrame({'datetime': test_datetimes, 
                           'count': np.expm1(Y_final)})
results_path = os.path.join('results', 'bike_sharing.csv')
submission.to_csv(results_path, index=False)

# %% [markdown]
# It seems that linear models are not great for that task because even with very basic hyperparameters tuning, Random Forest can achieve top 20% on Kaggle's LeaderBoard. It is a little suprising since tree-based models are not perfectly suited for time-series predictions. There are a lot of different ways to improve predicting power:
#
# 1. Check other flexible models like boosting.
# 2. Hyperparameters tuning.
# 3. Stacking or voting.
